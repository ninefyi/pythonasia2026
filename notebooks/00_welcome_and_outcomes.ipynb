# %% [markdown]
# # PythonAsia 2026 Notebook Workshop
#
# ## Building a Hybrid Search Recommender (Beginner Path)
#
# This notebook track is the primary classroom path. Run notebooks in order from `00` to `08`.

# %% [markdown]
# ## Learning Outcomes
#
# By the end of this workshop you can:
# 1. Explain chunking, embeddings, and cosine similarity.
# 2. Generate embeddings with VoyageAI.
# 3. Run keyword search and vector search in MongoDB Atlas.
# 4. Combine ranking lists with Reciprocal Rank Fusion (RRF).

# %%
agenda = [
    ("00", "Welcome and outcomes"),
    ("01", "Environment check"),
    ("02", "Chunking lab"),
    ("03", "Embeddings lab"),
    ("04", "Similarity lab"),
    ("05", "MongoDB search lab"),
    ("06", "Hybrid fusion lab"),
    ("07", "Mini challenge"),
    ("08", "Bridge to Django"),
]
for code, title in agenda:
    print(f"{code}: {title}")
