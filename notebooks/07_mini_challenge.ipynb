# %% [markdown]
# # 07 - Mini Challenge
#
# Try these beginner tasks and write short notes after each one.

# %% [markdown]
# ## Task 1
# Change your query wording in Notebook 05 and compare top results.
#
# Examples:
# - space mission
# - dream heist
# - mafia family

# %% [markdown]
# ## Task 2
# In Notebook 06, change RRF `k` from 60 to 10 and 100.
#
# Question: how sensitive is the final ranking?

# %% [markdown]
# ## Task 3
# Change vector `limit` and keyword `limit` in Notebook 05.
#
# Question: does larger candidate size improve quality for your query?
