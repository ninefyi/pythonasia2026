# %% [markdown]
# # 08 - Bridge to Django
#
# This notebook maps what you learned to the Django app in this repo.

# %% [markdown]
# ## Concept Mapping
#
# - Environment checks -> `test_voyage.py` and Django settings
# - Data model -> `django_app/recommendation/models.py`
# - Data ingestion -> `django_app/recommendation/management/commands/ingest.py`
# - Hybrid retrieval + RRF -> `django_app/recommendation/views.py`
# - User interface -> `django_app/recommendation/templates/recommendation/index.html`

# %%
from pathlib import Path

project_root = Path.cwd().parent if Path.cwd().name == "notebooks" else Path.cwd()
target_files = [
    "django_app/recommendation/models.py",
    "django_app/recommendation/management/commands/ingest.py",
    "django_app/recommendation/views.py",
    "django_app/recommendation/templates/recommendation/index.html",
]
for rel in target_files:
    full = project_root / rel
    print(rel, "->", "FOUND" if full.exists() else "MISSING")
